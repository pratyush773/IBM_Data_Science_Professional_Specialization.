# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# <b>Pratyush Sinha</b>
# Data Scienctist

# %% [markdown]
# <i>I am interested in data science because It uncovers the complex relations and helps in making smart decision</i>

# %% [markdown]
# ### Calculate the product of 5 and 10

# %%
5 * 10
# Out:
# 50

# %% [markdown]
# #### Bulletd list
#
# <br>
#
# -  hi
# -  all
#
# <br>
#
# #### Numbered list
#
# <br>
#
# 1. thanks
# 2. all
#
# <br>
#
# #### Table
#
# <br>
#
# Name        |Age         |intrest      |
# ---|---|--|
# Pratyush | 24 | Data Science
# Nipun | 21 | Machine learning
#
# <br>
#
# ### Motivational Picture
#
# ![Motivational pic](https://theyearofmagicaldreaming.files.wordpress.com/2014/07/ofcourseitshard.jpg)
